# %%
import pandas as pd
import numpy as np

df_o = pd.read_csv("new.csv")

df = df_o.iloc[:,5:73]

df = df.to_numpy()

new = []

for i in df:
    t = []
    for j in i:
        t.append(j[1:-1].split(" "))
    new.append(t)
        
print(new)



# np.mean([df[col].mean() for col in range(68)], axis=0)
# Out:
# '],
#   ['270', '514'],
#   ['286', '517'],
#   ['301', '511'],
#   ['323', '517'],
#   ['341', '532'],
#   ['325', '552'],
#   ['306', '563'],
#   ['289', '567'],
#   ['272', '566'],
#   ['251', '558'],
#   ['215', '600'],
#   ['243', '540'],
#   ['270', '532'],
#   ['287', '532'],
#   ['302', '530'],
#   ['330', '533'],
#   ['303', '538'],
#   ['288', '542'],
#   ['272', '541'],
#   ['250', '618'],
#   ['288', '623'],
#   ['326', '615']],
#  [['124', '380'],
#   ['126', '420'],
#   ['356', '604'],
#   ['387', '578'],
#   ['412', '544'],
#   ['425', '507'],
#   ['434', '467'],
#   ['440', '429'],
#   ['445', '389'],
#   ['143', '350'],
#   ['166', '331'],
#   ['197', '326'],
#   ['131', '458'],
#   ['227', '335'],
#   ['253', '350'],
#   ['310', '351'],
#   ['338', '339'],
#   ['369', '333'],
#   ['400', '342'],
#   ['421', '363'],
#   ['281', '378'],
#   ['281', '410'],
#   ['282', '442'],
#   ['137', '498'],
#   ['281', '474'],
#   ['243', '484'],
#   ['261', '492'],
# ...
